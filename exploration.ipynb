# %%
import ast
import pandas as pd
import re
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### Useful functions

# %%
def get_df_from_csv(path_file: str) -> pd.DataFrame:
    return pd.read_csv(path_file)

# %%
def display_df(df: pd.DataFrame) -> None:
    i = 0
    iteration = 2
    while i < len(df.columns):
        print(df.iloc[:, i:i+iteration].head())
        i += iteration

# %%
def get_translation_dict(df: pd.DataFrame, name_col: str, id_name_col: str) -> dict:
    translation_dict = dict()
    for row_collections in df[name_col]:
        if isinstance(row_collections, str):
            # if float, row_collections = Nan
            for row_collection in ast.literal_eval(row_collections):
                id_collection = row_collection[id_name_col]
                name_collection = row_collection['name']
                translation_dict[id_collection] = name_collection
    return translation_dict

# %% [markdown]
# ## EXTRACTING

# %%
path_file = r'data\train.csv'
train_df = get_df_from_csv(path_file)

# %% [markdown]
# ## EXPLORATY DATA ANALYSIS

# %%
display_df(train_df)
# Out:
#    id                              belongs_to_collection
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...
# 2   3                                                NaN
# 3   4                                                NaN
# 4   5                                                NaN
#      budget                                             genres
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#                             homepage    imdb_id
# 0                                NaN  tt2637294
# 1                                NaN  tt0368933
# 2  http://sonyclassics.com/whiplash/  tt2582802
# 3         http://kahaanithefilm.com/  tt1821480
# 4                                NaN  tt1380152
#   original_language                            original_title
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                      마린보이
#                                             overview  popularity
# 0  When Lou, who has become the "father of the In...    6.575393
# 1  Mia Thermopolis is now a college graduate and ...    8.248895
# 2  Under the direction of a ruthless instructor, ...   64.299990
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# 4  Marine Boy is the story of a former national s...    1.148070
#                         poster_path  \
# 0  /tQtWuwvMf0hCc2QR2tkolwl7c3c.jpg
# 1  /w9Z7A0GHEhIp7etpj0vyKOeU1Wx.jpg
# 2  /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg
# 3  /aTXRaPrWSinhcmCrcfJK17urp3F.jpg
# 4  /m22s7zvkVFDU9ir56PiiqIEWFdT.jpg
#
#                                 production_companies
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1        [{'name': 'Walt Disney Pictures', 'id': 2}]
# 2  [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# 3                                                NaN
# 4                                                NaN
#                                 production_countries release_date
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...      2/20/15
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...       8/6/04
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...     10/10/14
# 3            [{'iso_3166_1': 'IN', 'name': 'India'}]       3/9/12
# 4      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]       2/5/09
#    runtime                                   spoken_languages
# 0     93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1    113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2    105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3    122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4    118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#      status                                            tagline
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...
#     revenue
# 0  12314651
# 1  95149435
# 2  13092000
# 3  16000000
# 4   3923970

# %%
train_df.shape
# 3000 rows and 23 columns
train_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
# id                       3000 non-null int64
# belongs_to_collection    604 non-null object
# budget                   3000 non-null int64
# genres                   2993 non-null object
# homepage                 946 non-null object
# imdb_id                  3000 non-null object
# original_language        3000 non-null object
# original_title           3000 non-null object
# overview                 2992 non-null object
# popularity               3000 non-null float64
# poster_path              2999 non-null object
# production_companies     2844 non-null object
# production_countries     2945 non-null object
# release_date             3000 non-null object
# runtime                  2998 non-null float64
# spoken_languages         2980 non-null object
# status                   3000 non-null object
# tagline                  2403 non-null object
# title                    3000 non-null object
# Keywords                 2724 non-null object
# cast                     2987 non-null object
# crew                     2984 non-null object
# revenue                  3000 non-null int64
# dtypes: float64(2), int64(3), object(18)
# memory usage: 539.1+ KB

# %%
print(f"Unique ids : {train_df['id'].value_counts().size}")
# Out:
# Unique ids : 3000

# %%
for column in train_df.columns:
    series_unique_values = train_df[column].value_counts()
    nb_unique_values = series_unique_values.size
    print(f'"{column}"')
    if nb_unique_values == train_df.shape[0]:
        print(f'Only unique values, example of value: {train_df.loc[0, column]}\n')
    else:
        print(f'Nb of unique values: {nb_unique_values}')
        print(f'{train_df[column].value_counts()} \n')
# Out:
# "id"
# Only unique values, example of value: 1
#
# "belongs_to_collection"
# Nb of unique values: 422
# [{'id': 645, 'name': 'James Bond Collection', 'poster_path': '/HORpg5CSkmeQlAolx3bKMrKgfi.jpg', 'backdrop_path': '/6VcVl48kNKvdXOZfJPdarlUGOsk.jpg'}]                          16
# [{'id': 9735, 'name': 'Friday the 13th Collection', 'poster_path': '/uobgqpLQff9WvxGKE2OSvXv1RHm.jpg', 'backdrop_path': '/c7pMKwv5NzIN6N3KM4L8fYMTtPw.jpg'}]                    7
# [{'id': 937, 'name': 'The Pink Panther (Original) Collection', 'poster_path': '/xu6gZ0zGUSR8SC2QLKFaUrX2niM.jpg', 'backdrop_path': '/6KE7AguGR3UqwUn5RkzkoBc3MLy.jpg'}]         6
# [{'id': 34055, 'name': 'Pokémon Collection', 'poster_path': '/j5te0YNZAMXDBnsqTUDKIBEt8iu.jpg', 'backdrop_path': '/iGoYKA0TFfgSoZpG2u5viTJMGfK.jpg'}]                           5
# [{'id': 9338, 'name': 'Police Academy Collection', 'poster_path': '/1VRdXVy2FYlX4EtllnLKWK6kYDJ.jpg', 'backdrop_path': '/RhpI828r9EKPV4x0pyHiqCDZDQ.jpg'}]                      5
# [{'id': 8354, 'name': 'Ice Age Collection', 'poster_path': '/stQoHvo0q6ZcEkji2Z1wlAxKnDq.jpg', 'backdrop_path': '/2Mb92Ssoe1eUecvrCe2pEvgAlmv.jpg'}]                            4
# [{'id': 1575, 'name': 'Rocky Collection', 'poster_path': '/mCY5dMkSSFQufGCViI6jNUU6pXq.jpg', 'backdrop_path': '/w4h6gjdWPvmu5R9H6zeGDPo1ZuV.jpg'}]                              4
# [{'id': 9485, 'name': 'The Fast and the Furious Collection', 'poster_path': '/mCkqJf4ijbNoBWvJ0RTWZJuhJUA.jpg', 'backdrop_path': '/z5A5W3WYJc3UVEWljSGwdjDgQ0j.jpg'}]           4
# [{'id': 10455, 'name': "Child's Play Collection", 'poster_path': '/50aqbDvbOtdlZrje6Qk4ZvKM7dM.jpg', 'backdrop_path': '/AAhYXBVIEl6WgQnzfBsauTIC25.jpg'}]                       4
# [{'id': 8650, 'name': 'Transformers Collection', 'poster_path': '/vOUPHWV8aGXq4yYQ2csje5LdT6g.jpg', 'backdrop_path': '/zvZBNNDWd5LcsIBpDhJyCB2MDT7.jpg'}]                       4
# [{'id': 41437, 'name': 'Paranormal Activity Collection', 'poster_path': '/lYXAMmm9XlYmj5Dr4O9diLQVCJS.jpg', 'backdrop_path': '/hZMiAPeINRH0M2X1PBEgn6YdULy.jpg'}]               4
# [{'id': 5039, 'name': 'Rambo Collection', 'poster_path': '/feGOEOVrOLyjtEnVa88rQLgD3XY.jpg', 'backdrop_path': '/Yt2ZxbJv2HM842B6FNMr59Vhyb.jpg'}]                               4
# [{'id': 17255, 'name': 'Resident Evil Collection', 'poster_path': '/bqnMPsZr9vhjJIwLxc3XzHkYORM.jpg', 'backdrop_path': '/8utTJ9WoQeYcZ0Ztciv6auqwLXl.jpg'}]                     4
# [{'id': 8091, 'name': 'Alien Collection', 'poster_path': '/iVzIeC3PbG9BtDAudpwSNdKAgh6.jpg', 'backdrop_path': '/kB0Y3uGe9ohJa59Lk8UO9cUOxGM.jpg'}]                              4
# [{'id': 74508, 'name': '[REC] Collection', 'poster_path': '/jTA37dMZVUFej20EoM5SomKtnYi.jpg', 'backdrop_path': '/rDzuccVBZSyNVQ26hTRT0DvneVA.jpg'}]                             3
# [{'id': 86110, 'name': 'Diary of a Wimpy Kid Collection', 'poster_path': '/4Miizfzuds4ldROTff9vB0Z3EId.jpg', 'backdrop_path': '/hTbw2nLM44eE5m7ZIIXodcoDR1X.jpg'}]              3
# [{'id': 84, 'name': 'Indiana Jones Collection', 'poster_path': '/lpxDrACKJhbbGOlwVMNz5YCj6SI.jpg', 'backdrop_path': '/6kh59mZizZsttZPR0HAdXk6Ve2n.jpg'}]                        3
# [{'id': 263, 'name': 'The Dark Knight Collection', 'poster_path': '/bqS2lMgGkuodIXtDILFWTSWDDpa.jpg', 'backdrop_path': '/xfKot7lqaiW4XpL5TtDlVBA9ei9.jpg'}]                     3
# [{'id': 295, 'name': 'Pirates of the Caribbean Collection', 'poster_path': '/zT5UKFhq9nk97VGlBbAxlAK8UFN.jpg', 'backdrop_path': '/cnKAGbX1rDkAquF2V1wVkptHDJO.jpg'}]            3
# [{'id': 2366, 'name': 'The Jaws Collection', 'poster_path': '/fgraZdDCvAtBr0MHczmL6raonHd.jpg', 'backdrop_path': '/us13Po7SYoHl9wBNVcz04t0oh7F.jpg'}]                           3
# [{'id': 453993, 'name': 'The Wolverine Collection', 'poster_path': '/8Ht4a5A5Ypxh0PjbVoRTzm1kAu3.jpg', 'backdrop_path': '/QtSxEuCwcZSfCTMZfER3nHDVsG.jpg'}]                     3
# [{'id': 46512, 'name': 'Missing in Action Collection', 'poster_path': '/t1pfgb8r4Kx3qLN4H8vDZdfD50R.jpg', 'backdrop_path': '/6VIGk6OIqlKWrb4rjTvDklBfv1n.jpg'}]                 3
# [{'id': 91361, 'name': 'Halloween Collection', 'poster_path': '/2uqHV6YcD9jEL2WuJYjXiiuRDqd.jpg', 'backdrop_path': '/mmxf1sOe2T1sma0tH0TgTdcit1p.jpg'}]                         3
# [{'id': 151, 'name': 'Star Trek: The Original Series Collection', 'poster_path': '/zcB8KxHA4EapOoZZPAvwgmE1iGK.jpg', 'backdrop_path': '/9BQj9hq0aK6yM9Tm2NJ28jg572y.jpg'}]      3
# [{'id': 87118, 'name': 'Cars Collection', 'poster_path': '/uq3N2SFj1Y06zA6LzCQPkmBdaaE.jpg', 'backdrop_path': '/yPyhZ5OpYs68Bb8u0PZ1tH0QIgd.jpg'}]                              3
# [{'id': 90863, 'name': 'Rush Hour Collection', 'poster_path': '/pTjvzlYByJuZ4TTkmlHIe4aDFy2.jpg', 'backdrop_path': '/uoDt3eCCKpcxSQVWjPTgN8T0gjm.jpg'}]                         3
# [{'id': 4563, 'name': 'The Vengeance Collection', 'poster_path': '/ilyS5xmHzMtTq4ngVRNKvZEbSRo.jpg', 'backdrop_path': '/t5zZZOvXK8m5z1omMdEEWcL6ywl.jpg'}]                      3
# [{'id': 1709, 'name': 'Planet of the Apes Original Collection', 'poster_path': '/r7TBDEcpBAuFoqdtUz7z2nSeFej.jpg', 'backdrop_path': '/eYf3GRnuVCgeFQfEo0qK7ua5rCR.jpg'}]        3
# [{'id': 173344, 'name': 'Qatsi Collection', 'poster_path': '/AlE6QJc87zH5vYw6AI779ywRZG6.jpg', 'backdrop_path': '/2pRLc3z0jE1WkFJLCZyITtYjo08.jpg'}]                            3
# [{'id': 4246, 'name': 'Scary Movie Collection', 'poster_path': '/nsD3xlHagixzVYaE57EESeVYro7.jpg', 'backdrop_path': '/qPRZ1HpvpPM81cBTwNKXlqtH9MT.jpg'}]                        3
#                                                                                                                                                                                ..
# [{'id': 476961, 'name': 'Goon Collection', 'poster_path': '/uHKl6JXibu1MstyAlT1d3I4YKb6.jpg', 'backdrop_path': None}]                                                           1
# [{'id': 51509, 'name': 'Meet the Parents Collection', 'poster_path': '/WFkinadVm4NRynRKuUcaLFNIDx.jpg', 'backdrop_path': '/7UWRq79VHc58QXTSn57UsOUKQLZ.jpg'}]                   1
# [{'id': 221539, 'name': 'Dracula (Universal Series)', 'poster_path': '/srgkikGqQD32mhaq8wT6Qz2eLcD.jpg', 'backdrop_path': '/sdbStuQ5qEPZqqWUlNlBd0dPtBT.jpg'}]                  1
# [{'id': 8936, 'name': 'Bridget Jones Collection', 'poster_path': '/fB3BE3TL85Wh7dxNJf226IYQCp.jpg', 'backdrop_path': '/jiS4x140miaEH524CAFTvuxrcZ1.jpg'}]                       1
# [{'id': 134011, 'name': 'The Fugitive / U.S. Marshals Collection', 'poster_path': '/idhUzfuEC24PTYhkWasivjoA3O0.jpg', 'backdrop_path': '/9xbrJQoHkTgkXY8oDsTmND0FiEX.jpg'}]     1
# [{'id': 96871, 'name': 'Father of the Bride Collection', 'poster_path': '/nts4iOmNnq7GNicycMJ9pSAn204.jpg', 'backdrop_path': '/7qwE57OVZmMJChBpLEbJEmzUydk.jpg'}]               1
# [{'id': 64750, 'name': 'Blair Witch Collection', 'poster_path': '/qDQuKJZYLHrs1Ej64tYYFooFxc1.jpg', 'backdrop_path': '/e5GwLq0zBer3SuSJZodcNROnT6Z.jpg'}]                       1
# [{'id': 43064, 'name': 'Speed Collection', 'poster_path': '/9poztwq7SXjEETRdWXcJsl58kxV.jpg', 'backdrop_path': '/75mSNcKIkfZSjXDgytC8UFe6vBl.jpg'}]                             1
# [{'id': 255478, 'name': "Cowgirls n' Angels Collection", 'poster_path': '/p8hwMZbeNe6qQFlblm1DjKrvYOu.jpg', 'backdrop_path': None}]                                             1
# [{'id': 98513, 'name': 'Behind Enemy Lines Collection', 'poster_path': '/baDDWPQgZyBKiDNeipLJ9LEZ5BX.jpg', 'backdrop_path': '/5sMWk8wutGCFAM7MAFPQJyc0ny0.jpg'}]                1
# [{'id': 87359, 'name': 'Mission: Impossible Collection', 'poster_path': '/gwyJPIhCK4Xz2WogeBnhCSQfUek.jpg', 'backdrop_path': '/49L0c5utmm0A4BkeDafM9BOhyBT.jpg'}]               1
# [{'id': 288491, 'name': 'Dolphin Tale Collection', 'poster_path': '/3Xav3CJrYtUBQ7mB2lKTJ7TSn1q.jpg', 'backdrop_path': '/hEji18uGq2IwKWs2IpWFw9EwlJp.jpg'}]                     1
# [{'id': 312735, 'name': 'Annie Collection', 'poster_path': '/gKQghFIfPL7aviK7OonirYgnaMa.jpg', 'backdrop_path': None}]                                                          1
# [{'id': 416468, 'name': 'World War Z Collection', 'poster_path': '/gDObITaWQUaS9Par6ntLyvq1JrK.jpg', 'backdrop_path': None}]                                                    1
# [{'id': 92012, 'name': 'Happy Feet Collection', 'poster_path': '/pYbF2FAi2MEVshl8jCDNTRNdTF0.jpg', 'backdrop_path': '/b9CLLxKsh63AHEkGE9nz9bupQqh.jpg'}]                        1
# [{'id': 446782, 'name': 'The Disappearance Of Eleanor Rigby', 'poster_path': '/xg3F3P9becOjNqYHlMuBcWPXU5G.jpg', 'backdrop_path': '/3eyH0cwrBdrSCwKF24oOwy8fO7O.jpg'}]          1
# [{'id': 369004, 'name': 'Borsalino Collection', 'poster_path': None, 'backdrop_path': None}]                                                                                    1
# [{'id': 106784, 'name': 'Love in the City Collection', 'poster_path': '/xhRO4HSdJv2i5MQIW8nt6PC3JWK.jpg', 'backdrop_path': '/6ZPtYW6h1M4K3URZMr7ZBgmTv8N.jpg'}]                 1
# [{'id': 96677, 'name': 'Red Cliff Collection', 'poster_path': '/3KFgWRuNk3d9QGCnQUXKJSsfrLC.jpg', 'backdrop_path': '/46G7BAqK6LDAxIFVLq926rzN65o.jpg'}]                         1
# [{'id': 123255, 'name': 'Prom Night Collection', 'poster_path': '/tHhPnpJad4RVICIwaeERIq63ARg.jpg', 'backdrop_path': None}]                                                     1
# [{'id': 122776, 'name': 'Kvartet I Collection', 'poster_path': '/rleIVHx2kG8lYfHUsBh3CkD4Jnc.jpg', 'backdrop_path': '/c7SHTYbGPb3DzO484z0aYFx5u0q.jpg'}]                        1
# [{'id': 131295, 'name': 'Captain America Collection', 'poster_path': '/2tOgiY533JSFp7OrVlkeRJvsZpI.jpg', 'backdrop_path': '/nZSYqitBkAvmoq5IrsGsSWuhSC8.jpg'}]                  1
# [{'id': 97445, 'name': 'Air Bud Collection', 'poster_path': '/6uJ2GXA5kBskJx6emTuHyp2S3ww.jpg', 'backdrop_path': '/3iROV2GdrAFz6lbrGneQLt8lc7K.jpg'}]                           1
# [{'id': 91427, 'name': 'Agent Cody Banks Collection', 'poster_path': '/nQZ1TuxTEFrZLEU02kTTeKogFbX.jpg', 'backdrop_path': '/gh0OZpG16E5LtTAkCRkr5j0v1Fh.jpg'}]                  1
# [{'id': 91698, 'name': 'Chili Palmer Collection', 'poster_path': '/ae3smJDdWrMJ77tDpYOrpo4frKq.jpg', 'backdrop_path': '/uWaANGQeoSs5vSP1CWtlkDrkqei.jpg'}]                      1
# [{'id': 437451, 'name': 'Cinderella Story Collection', 'poster_path': '/65raP1FRJpPC5GVWVvemQ3kLAKG.jpg', 'backdrop_path': '/iVqkNuy2jpcurdk2ZH2iAexJTo6.jpg'}]                 1
# [{'id': 53159, 'name': 'The Santa Clause Collection', 'poster_path': '/1h8iA6i2DpPhsHC65nUB2voVnm5.jpg', 'backdrop_path': '/jQiwVHJN1rsS4DqhF7hlYZTYCH.jpg'}]                   1
# [{'id': 416491, 'name': 'Major Korenev Trilogy', 'poster_path': '/3olGvGn88TvfB7NCyJge5Ivwus5.jpg', 'backdrop_path': '/vtM7Cxm7TUAWeZH2qfrbszZCnpQ.jpg'}]                       1
# [{'id': 87186, 'name': 'The Boondock Saints Collection', 'poster_path': '/u4hp2I1DgWw2ZnkX2VTZDixGP87.jpg', 'backdrop_path': '/kdxXEiS3sDB7pvQapiqiTRbwkKr.jpg'}]               1
# [{'id': 313576, 'name': 'Hot Tub Time Machine Collection', 'poster_path': '/iEhb00TGPucF0b4joM1ieyY026U.jpg', 'backdrop_path': '/noeTVcgpBiD48fDjFVic1Vz7ope.jpg'}]             1
# Name: belongs_to_collection, Length: 422, dtype: int64
#
# "budget"
# Nb of unique values: 406
# 0            812
# 15000000      72
# 40000000      71
# 25000000      71
# 20000000      68
# 5000000       68
# 30000000      65
# 12000000      54
# 10000000      53
# 50000000      50
# 35000000      46
# 60000000      42
# 4000000       40
# 2000000       39
# 6000000       39
# 8000000       38
# 13000000      36
# 7000000       34
# 3000000       34
# 18000000      31
# 80000000      27
# 16000000      27
# 14000000      26
# 11000000      24
# 28000000      22
# 9000000       21
# 22000000      21
# 70000000      20
# 100000000     20
# 19000000      20
#             ...
# 17820000       1
# 46000000       1
# 93000000       1
# 1350000        1
# 27000          1
# 1821052        1
# 7920000        1
# 762241         1
# 7400000        1
# 11930000       1
# 590235         1
# 13400000       1
# 12468389       1
# 3512454        1
# 1752000        1
# 290000         1
# 1688000        1
# 8575000        1
# 27220000       1
# 63600000       1
# 645180         1
# 125000         1
# 4361898        1
# 3600000        1
# 93             1
# 3750000        1
# 113            1
# 891000         1
# 5400000        1
# 24554          1
# Name: budget, Length: 406, dtype: int64
#
# "genres"
# Nb of unique values: 872
# [{'id': 18, 'name': 'Drama'}]                                                                                                                                                                     266
# [{'id': 35, 'name': 'Comedy'}]                                                                                                                                                                    186
# [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]                                                                                                                                   108
# [{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}]                                                                                                                                   88
# [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}]                                                                                                                                        85
# [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]                                                                                                      65
# [{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}]                                                                                                                                     47
# [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}]                                                                                                                                      44
# [{'id': 99, 'name': 'Documentary'}]                                                                                                                                                                44
# [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}]                                                                                                         33
# [{'id': 27, 'name': 'Horror'}]                                                                                                                                                                     31
# [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}]                                                                                                                                         30
# [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}]                                                                                                                                        29
# [{'id': 28, 'name': 'Action'}, {'id': 35, 'name': 'Comedy'}]                                                                                                                                       29
# [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}]                                                                                                                                     28
# [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}]                                                                                                                                       27
# [{'id': 28, 'name': 'Action'}, {'id': 80, 'name': 'Crime'}, {'id': 53, 'name': 'Thriller'}]                                                                                                        25
# [{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}]                                                                                                        22
# [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'name': 'Crime'}]                                                                                                                                        21
# [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}]                                                                                                      20
# [{'id': 10749, 'name': 'Romance'}, {'id': 18, 'name': 'Drama'}]                                                                                                                                    19
# [{'id': 28, 'name': 'Action'}, {'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}]                                                                           19
# [{'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]                                                                                                                                    18
# [{'id': 28, 'name': 'Action'}]                                                                                                                                                                     17
# [{'id': 53, 'name': 'Thriller'}]                                                                                                                                                                   17
# [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'name': 'War'}]                                                                                                                                        16
# [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}]                                                                                                                                         16
# [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'name': 'Mystery'}, {'id': 53, 'name': 'Thriller'}]                                                                                                    15
# [{'id': 28, 'name': 'Action'}, {'id': 35, 'name': 'Comedy'}, {'id': 80, 'name': 'Crime'}]                                                                                                          14
# [{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}]                                                                                                                                        13
#                                                                                                                                                                                                  ...
# [{'id': 10751, 'name': 'Family'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 12, 'name': 'Adventure'}]                                                                                          1
# [{'id': 12, 'name': 'Adventure'}, {'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, {'id': 9648, 'name': 'Mystery'}]                                                                    1
# [{'id': 28, 'name': 'Action'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 53, 'name': 'Thriller'}, {'id': 12, 'name': 'Adventure'}]                                                             1
# [{'id': 27, 'name': 'Horror'}, {'id': 14, 'name': 'Fantasy'}, {'id': 35, 'name': 'Comedy'}]                                                                                                         1
# [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 18, 'name': 'Drama'}, {'id': 9648, 'name': 'Mystery'}, {'id': 10749, 'name': 'Romance'}, {'id': 14, 'name': 'Fantasy'}]      1
# [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 16, 'name': 'Animation'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 53, 'name': 'Thriller'}]                            1
# [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 10752, 'name': 'War'}]                                                                                                       1
# [{'id': 878, 'name': 'Science Fiction'}, {'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}]                                                                                               1
# [{'id': 12, 'name': 'Adventure'}, {'id': 18, 'name': 'Drama'}, {'id': 28, 'name': 'Action'}, {'id': 10749, 'name': 'Romance'}, {'id': 10751, 'name': 'Family'}]                                     1
# [{'id': 10402, 'name': 'Music'}, {'id': 12, 'name': 'Adventure'}, {'id': 16, 'name': 'Animation'}, {'id': 28, 'name': 'Action'}, {'id': 35, 'name': 'Comedy'}]                                      1
# [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}, {'id': 14, 'name': 'Fantasy'}, {'id': 878, 'name': 'Science Fiction'}]                                 1
# [{'id': 18, 'name': 'Drama'}, {'id': 37, 'name': 'Western'}, {'id': 80, 'name': 'Crime'}]                                                                                                           1
# [{'id': 10402, 'name': 'Music'}, {'id': 35, 'name': 'Comedy'}]                                                                                                                                      1
# [{'id': 27, 'name': 'Horror'}, {'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10752, 'name': 'War'}]                                              1
# [{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}, {'id': 14, 'name': 'Fantasy'}, {'id': 9648, 'name': 'Mystery'}]                                                                      1
# [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'name': 'Drama'}, {'id': 27, 'name': 'Horror'}]                                                                                                         1
# [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'name': 'Mystery'}, {'id': 27, 'name': 'Horror'}]                                                                                                        1
# [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}, {'id': 37, 'name': 'Western'}]                                                                         1
# [{'id': 28, 'name': 'Action'}, {'id': 27, 'name': 'Horror'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 53, 'name': 'Thriller'}]                                                                1
# [{'id': 12, 'name': 'Adventure'}, {'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}]                                                                                                     1
# [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 27, 'name': 'Horror'}]                                                                        1
# [{'id': 12, 'name': 'Adventure'}, {'id': 10752, 'name': 'War'}, {'id': 10749, 'name': 'Romance'}]                                                                                                   1
# [{'id': 99, 'name': 'Documentary'}, {'id': 18, 'name': 'Drama'}, {'id': 10402, 'name': 'Music'}]                                                                                                    1
# [{'id': 16, 'name': 'Animation'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 10751, 'name': 'Family'}]                                                                                          1
# [{'id': 28, 'name': 'Action'}, {'id': 10751, 'name': 'Family'}, {'id': 14, 'name': 'Fantasy'}]                                                                                                      1
# [{'id': 16, 'name': 'Animation'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}]                                                                1
# [{'id': 35, 'name': 'Comedy'}, {'id': 53, 'name': 'Thriller'}, {'id': 80, 'name': 'Crime'}]                                                                                                         1
# [{'id': 10751, 'name': 'Family'}, {'id': 99, 'name': 'Documentary'}, {'id': 12, 'name': 'Adventure'}]                                                                                               1
# [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 16, 'name': 'Animation'}, {'id': 10751, 'name': 'Family'}]                                                                  1
# [{'id': 14, 'name': 'Fantasy'}, {'id': 16, 'name': 'Animation'}, {'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}, {'id': 10751, 'name': 'Family'}]                                    1
# Name: genres, Length: 872, dtype: int64
#
# "homepage"
# Nb of unique values: 941
# http://www.transformersmovie.com/                                                  4
# http://www.thehobbit.com/                                                          2
# http://www.lordoftherings.net/                                                     2
# http://www.foxsearchlight.com/winwin/                                              1
# http://www.foxsearchlight.com/theartofgettingby/                                   1
# http://whatjusthappenedfilm.com/                                                   1
# http://www.thefourthkind.net/                                                      1
# http://stxmovies.com/freestateofjones/                                             1
# http://www.sonypictures.com/movies/residentevil/index.html                         1
# http://www.topfivemovie.com/                                                       1
# http://toystory.disney.com/toy-story                                               1
# http://www.thefilmfactory.co.uk/hallamfoe/                                         1
# http://www.13assassins.com/                                                        1
# http://www.foxsearchlight.com/daywatch/                                            1
# http://www.thedarkknightrises.com/                                                 1
# http://www.d-9.com/                                                                1
# http://www.blackdynamitemovie.com                                                  1
# http://www.meetnorbit.com/                                                         1
# http://www.magpictures.com/touchyfeely/                                            1
# http://thetownmovie.warnerbros.com/                                                1
# http://asoundofthunder.warnerbros.com/                                             1
# http://www.magpictures.com/profile.aspx?id=9833910c-fd4a-4fcb-a734-b3d252473a03    1
# http://www.foxsearchlight.com/boysdontcry/                                         1
# http://www.livebynight.movie/                                                      1
# http://wwws.warnerbros.co.jp/L-movie                                               1
# http://www.americanhustle-movie.com/                                               1
# https://www.facebook.com/GIFTmovie                                                 1
# http://www.sonypictures.com/homevideo/freedomland/                                 1
# http://www.imdb.com/title/tt0099674/                                               1
# http://www.foxsearchlight.com/ourfamilywedding/                                    1
#                                                                                   ..
# http://www.kennythemovie.com/                                                      1
# http://www.blankcityfilm.com/                                                      1
# http://www.filminfocus.com/focusfeatures/film/sin_nombre                           1
# http://www.italianjobmovie.com/                                                    1
# http://www.rabbitholefilm.com/                                                     1
# http://gravitymovie.warnerbros.com/                                                1
# http://www.anomalisa.com/                                                          1
# http://www.pixels-movie.com/                                                       1
# http://www.oneforthemoneyfilm.com/index2.html                                      1
# http://www.meetmonicavelour.com/#/home                                             1
# http://frompradatonadamovie.com/                                                   1
# http://www.kaiji-movie.jp                                                          1
# http://www.iceagemovies.com/films/ice-age-dawn-of-the-dinosaurs                    1
# http://www.wrathofthetitansmovie.org                                               1
# http://www.mgm.com/view/movie/1891/The-Spy-Who-Loved-Me/                           1
# http://getsmartmovie.warnerbros.com/                                               1
# http://www.sexdrivethemovie.com/                                                   1
# http://www.billandted.org/                                                         1
# http://www.sonypictures.com/homevideo/firedup/                                     1
# http://www.sonypictures.com/homevideo/swat/                                        1
# http://www.thewartapes.com                                                         1
# http://exmachina-movie.com/                                                        1
# http://www.theunbornmovie.net/                                                     1
# http://www.beetlequeen.com/                                                        1
# http://www.adeleblancsec-lefilm.com/                                               1
# http://phoenixforgotten.com/                                                       1
# http://www.foxsearchlight.com/mylifeinruins/                                       1
# https://www.facebook.com/BreatheInMovie                                            1
# http://www.zerodarkthirty-movie.com/site/                                          1
# http://www.thedoublemovie.com/                                                     1
# Name: homepage, Length: 941, dtype: int64
#
# "imdb_id"
# Only unique values, example of value: tt2637294
#
# "original_language"
# Nb of unique values: 36
# en    2575
# fr      78
# ru      47
# es      43
# hi      42
# ja      37
# it      24
# cn      20
# ko      20
# zh      19
# de      18
# ta      16
# sv       8
# pt       6
# nl       6
# da       5
# fa       5
# ro       4
# hu       3
# tr       3
# fi       2
# te       2
# pl       2
# no       2
# ml       2
# id       1
# ur       1
# cs       1
# sr       1
# vi       1
# he       1
# el       1
# nb       1
# mr       1
# bn       1
# ar       1
# Name: original_language, dtype: int64
#
# "original_title"
# Nb of unique values: 2975
# Hercules                                       2
# The Gift                                       2
# The Double                                     2
# Casino Royale                                  2
# Ben-Hur                                        2
# The Other Woman                                2
# Red Dawn                                       2
# King Kong                                      2
# Hot Pursuit                                    2
# Lolita                                         2
# Bad Boys                                       2
# The Women                                      2
# Joshua                                         2
# Logan                                          2
# The Three Musketeers                           2
# Unknown                                        2
# The Magnificent Seven                          2
# Scarface                                       2
# Alone in the Dark                              2
# Anna Karenina                                  2
# Sahara                                         2
# Priest                                         2
# Deadfall                                       2
# Fantastic Four                                 2
# Black Sheep                                    2
# The Legend Fong Sai Yuk                        1
# Hello, Dolly!                                  1
# The Perfect Storm                              1
# Jaws 3-D                                       1
# Tuck Everlasting                               1
#                                               ..
# And You Thought Your Parents Were Weird        1
# Cipolla Colt                                   1
# Honey I Blew Up the Kid                        1
# Green Zone                                     1
# Bunny and the Bull                             1
# Starsky & Hutch                                1
# Phoenix Forgotten                              1
# Monster in a Box                               1
# Ирония судьбы. Продолжение                     1
# Cleopatra                                      1
# Identity                                       1
# Стиляги                                        1
# The Devil's Violinist                          1
# The Phantom                                    1
# Pirates of the Caribbean: On Stranger Tides    1
# Get on the Bus                                 1
# Excalibur                                      1
# The Bourne Legacy                              1
# Love Is Strange                                1
# Modern Times                                   1
# The Call                                       1
# Dracula 2000                                   1
# Mistress America                               1
# Kicking and Screaming                          1
# दिल से                                         1
# House of Wax                                   1
# Cats & Dogs                                    1
# Man of Tai Chi                                 1
# Murder by Numbers                              1
# Ghosts Can't Do It                             1
# Name: original_title, Length: 2975, dtype: int64
#
# "overview"
# Nb of unique values: 2992
# Everyone deserves a chance to follow their dreams, but some people only get one shot. Tyler Gage is a rebel from the wrong side of Baltimore's tracks and the only thing that stands between him and an unfulfilled life are his dreams of one day making it out of there. Nora is a privileged ballet dancer attending Baltimore's ultra-elite Maryland School of the Arts                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# Based on the real-life Richard Speck murders, amoral, nearly psychotic killer Warren Stacey (Gene Davis) is a serial killer who has murdered a number of women; he stabs them while they are naked to minimize leaving any physical evidence. Police detective Leo Kessler (Charles Bronson) is convinced of Stacey‚Äôs guilt and, over the objections of his partner, plants evidence to get him behind bars. When Stacey is released on a technicality, he threatens to go after Kessler and his family, leaving Kessler to defend himself against a killer with little help from the police.                                                                                                                                                                                                                                                                   1
# Down-on-their luck brothers, Lars and Ernie Smuntz, aren't happy with the crumbling old mansion they inherit... until they discover the estate is worth millions. Before they can cash in, they have to rid the house of it's single, stubborn occupant: a tiny and tenacious mouse.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# Jerry, a small-town Minnesota car salesman is bursting at the seams with debt... but he's got a plan. He's going to hire two thugs to kidnap his wife in a scheme to collect a hefty ransom from his wealthy father-in-law. It's going to be a snap and nobody's going to get hurt... until people start dying. Enter Police Chief Marge, a coffee-drinking, parka-wearing - and extremely pregnant - investigator who'll stop at nothing to get her man. And if you think her small-time investigative skills will give the crooks a run for their ransom... you betcha!                                                                                                                                                                                                                                                                                         1
# A tragic love story set in East Berlin with the backdrop of an undercover Stasi controlled culture. Stasi captain Wieler is ordered to follow author Dreyman and plunges deeper and deeper into his life until he reaches the threshold of doubting the system.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# It is now summer in the Parker family; and the usual amount of numerous events are happening in their separate lives. Ralphie is searching for the perfect top to use to beat the school bully with, the Old Man is in battle with their hillbilly neighbors, the Bumpus, while eagerly awaiting the discovery of the perfect fishing spot, and the Mother is attempting to collect all of the pieces of a glass china set at a local movie theater.                                                                                                                                                                                                                                                                                                                                                                                                              1
# The story concerns a hapless civil servant who gets more than he bargained for when he moves into an apartment with a gay fashion student and finds himself on the catwalk. The film sets out to explore the difficulties for young people in keeping their identities in a fast moving culture of drugs and clubs.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# Three Braves is the story of three extraordinary children who rise from the most unlikeliest of places and save their town from the evils plague it. Equipped with courage and super powers,11 year old Amna, Saadi and Kamil battle against the odds and stand up to injustice to restore peace and harmony in their once thriving community And live a very happy life.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         1
# Storks deliver babies‚Ä¶or at least they used to. Now they deliver packages for a global internet retail giant. Junior, the company‚Äôs top delivery stork, is about to be promoted when he accidentally activates the Baby Making Machine, producing an adorable and wholly unauthorized baby girl...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# Based on the international best selling book. The true feel good story of how James Bowen, a busker and recovering drug addict, had his life transformed when he met a stray ginger cat.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# Hotshot real estate salesman Daryl has a bad cocaine habit. After embezzling his company's money, he wakes up next to a girl who overdosed. To hide from the police, he checks into a rehabilitation program guaranteeing anonymity. Under the mentorship of counselor Craig, Daryl accepts that he has a substance abuse problem. As he falls in love with fellow patient Charlie, Daryl begins committing to a newly sober life.                                                                                                                                                                                                                                                                                                                                                                                                                                1
# An ordinary word processor has the worst night of his life after he agrees to visit a girl in Soho whom he met that evening at a coffee shop.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# Four Weddings And A Funeral is a British comedy about a British Man named Charles and an American Woman named Carrie who go through numerous weddings before they determine if they are right for one another.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# Juno Mak‚Äôs debut feature Rigor Mortis is an eerie and chilling, contemporary action- and special effects-laden homage to the classic Chinese vampire movies of the 1980s.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# A comedy that pays tribute to the science fiction genre -- specifically, the sub-genre of time travel. But here the alternate reality is contemporary New York City where past and future experiences of trust, commitment and denial are cleverly put to the test. Just as Ruby is beginning to relish her first-ever healthy relationship, Sam begins muttering about being a time traveler from the year 2470.                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# A high-school gym teacher has big plans for the summer, but is forced to cancel them to teach a "bonehead" English class for misfit goof-off students. Fortunately, his unconventional brand of teaching fun field trips begins to connect with them, and even inspires ardor in some.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# Under constant attack by monstrous creatures called Angels that seek to eradicate humankind, U.N. Special Agency NERV introduces two new EVA pilots to help defend the city of Tokyo-3: the mysterious Makinami Mari Illustrous and the intense Asuka Langley Shikinami. Meanwhile, Gendo Ikari and SEELE proceed with a secret project that involves both Rei and Shinji.  The film was retitled "Evangelion: 2.22" for its DVD/Blu-Ray release.                                                                                                                                                                                                                                                                                                                                                                                                                 1
# ...
# [{'credit_id': '52fe45da9251416c75064bd3', 'department': 'Production', 'gender': 2, 'id': 19292, 'job': 'Producer', 'name': 'Adam Sandler', 'profile_path': '/tv9V6QsuZ3bcp4ciUJjwjcc4qAg.jpg'}, {'credit_id': '52fe45da9251416c75064bd9', 'department': 'Production', 'gender': 2, 'id': 20821, 'job': 'Producer', 'name': 'Jack Giarraputo', 'profile_path': None}, {'credit_id': '52fe45da9251416c75064be3', 'department': 'Writing', 'gender': 2, 'id': 66563, 'job': 'Screenplay', 'name': 'Fred Wolf', 'profile_path': None}, {'credit_id': '52fe45da9251416c75064b8d', 'department': 'Directing', 'gender': 2, 'id': 66563, 'job': 'Director', 'name': 'Fred Wolf', 'profile_path': None}, {'credit_id': '52fe45da9251416c75064be9', 'department': 'Writing', 'gender': 2, 'id': 81209, 'job': 'Screenplay', 'name': 'Peter Gaulke', 'profile_path': None}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# [{'credit_id': '52fe448dc3a36847f809c91d', 'department': 'Directing', 'gender': 2, 'id': 769, 'job': 'Director', 'name': 'Martin Brest', 'profile_path': '/uBdfVZ2YBpnMj24UEviiNxbQgrt.jpg'}, {'credit_id': '52fe448dc3a36847f809c923', 'department': 'Writing', 'gender': 2, 'id': 769, 'job': 'Screenplay', 'name': 'Martin Brest', 'profile_path': '/uBdfVZ2YBpnMj24UEviiNxbQgrt.jpg'}, {'credit_id': '52fe448dc3a36847f809c929', 'department': 'Production', 'gender': 0, 'id': 20802, 'job': 'Producer', 'name': 'Casey Silver', 'profile_path': None}, {'credit_id': '52fe448dc3a36847f809c92f', 'department': 'Production', 'gender': 2, 'id': 769, 'job': 'Producer', 'name': 'Martin Brest', 'profile_path': '/uBdfVZ2YBpnMj24UEviiNxbQgrt.jpg'}, {'credit_id': '52fe448dc3a36847f809c935', 'department': 'Editing', 'gender': 1, 'id': 53645, 'job': 'Editor', 'name': 'Julie Monroe', 'profile_path': None}, {'credit_id': '52fe448dc3a36847f809c93b', 'department': 'Editing', 'gender': 2, 'id': 909, 'job': 'Editor', 'name': 'Billy Weber', 'profile_path': None}, {'credit_id': '52fe448dc3a36847f809c941', 'department': 'Camera', 'gender': 2, 'id': 2950, 'job': 'Director of Photography', 'name': 'Robert Elswit', 'profile_path': None}, {'credit_id': '562647a99251413bda002c95', 'department': 'Sound', 'gender': 2, 'id': 11098, 'job': 'Original Music Composer', 'name': 'John Powell', 'profile_path': '/fFRYoiZxBtP4Gs0CAphU7F5mDk.jpg'}, {'credit_id': '5627488fc3a3682791001a3d', 'department': 'Costume & Make-Up', 'gender': 2, 'id': 605, 'job': 'Costume Design', 'name': 'Michael Kaplan', 'profile_path': '/pgME9OWsN2y3UZw1OsXbqmN2fEx.jpg'}, {'credit_id': '562748bb92514137cf001a55', 'department': 'Art', 'gender': 2, 'id': 3117, 'job': 'Production Design', 'name': 'Gary Frutkoff', 'profile_path': None}, {'credit_id': '562748e992514137cd0019cd', 'department': 'Production', 'gender': 1, 'id': 2242, 'job': 'Casting', 'name': 'Ellen Lewis', 'profile_path': None}, {'credit_id': '56274a2492514137c400194f', 'department': 'Production', 'gender': 2, 'id': 6341, 'job': 'Executive Producer', 'name': 'John Hardy', 'profile_path': None}, {'credit_id': '56274a3dc3a36827860017fe', 'department': 'Production', 'gender': 0, 'id': 1117840, 'job': 'Associate Producer', 'name': 'Frederic W. Brost', 'profile_path': None}, {'credit_id': '56274a5592514137c9001982', 'department': 'Production', 'gender': 1, 'id': 10390, 'job': 'Associate Producer', 'name': 'Amy Sayres', 'profile_path': None}, {'credit_id': '56274a71c3a368277a001bfa', 'department': 'Art', 'gender': 1, 'id': 957368, 'job': 'Set Decoration', 'name': 'Maggie Martin', 'profile_path': None}, {'credit_id': '56274aafc3a368278f001a3e', 'department': 'Art', 'gender': 1, 'id': 33455, 'job': 'Art Direction', 'name': 'Sue Chan', 'profile_path': None}, {'credit_id': '56274adcc3a368278f001a44', 'department': 'Directing', 'gender': 0, 'id': 1377239, 'job': 'Script Supervisor', 'name': 'Wilma Garscadden-Gahret', 'profile_path': None}, {'credit_id': '56274b6092514137bd0019e3', 'department': 'Lighting', 'gender': 0, 'id': 1194472, 'job': 'Gaffer', 'name': 'James Plannette', 'profile_path': None}, {'credit_id': '56274bc7c3a368277f001c5f', 'department': 'Camera', 'gender': 2, 'id': 18095, 'job': 'Still Photographer', 'name': 'Phillip V. Caruso', 'profile_path': None}, {'credit_id': '5665da66c3a36806aa0007a5', 'department': 'Sound', 'gender': 2, 'id': 1347755, 'job': 'Music Editor', 'name': 'John Finklea', 'profile_path': None}, {'credit_id': '5665da78c3a36806a200079f', 'department': 'Sound', 'gender': 0, 'id': 113046, 'job': 'Supervising Sound Editor', 'name': 'David Giammarco', 'profile_path': None}, {'credit_id': '5665da9492514179e9000788', 'department': 'Sound', 'gender': 2, 'id': 1300755, 'job': 'Sound Effects Editor', 'name': 'Scott A. Jennings', 'profile_path': '/bLmsE5YdI7FcZOyLzblZBQrF386.jpg'}, {'credit_id': '5665db929251411ca10001ca', 'department': 'Editing', 'gender': 0, 'id': 14382, 'job': 'Dialogue Editor', 'name': 'George H. Anderson', 'profi ...
# [{'credit_id': '52fe4258c3a36847f8017291', 'department': 'Directing', 'gender': 2, 'id': 468, 'job': 'Director', 'name': 'Stephen Daldry', 'profile_path': '/1MdxJ4q6Iw1BITZ4mlhDbAtFzMO.jpg'}, {'credit_id': '52fe4258c3a36847f8017297', 'department': 'Production', 'gender': 2, 'id': 8401, 'job': 'Producer', 'name': 'Mark Huffam', 'profile_path': None}, {'credit_id': '52fe4258c3a36847f801729d', 'department': 'Writing', 'gender': 2, 'id': 8403, 'job': 'Screenplay', 'name': 'David Hare', 'profile_path': None}, {'credit_id': '52fe4258c3a36847f80172ef', 'department': 'Production', 'gender': 2, 'id': 8448, 'job': 'Producer', 'name': 'Robert Fox', 'profile_path': None}, {'credit_id': '52fe4259c3a36847f80172f5', 'department': 'Production', 'gender': 2, 'id': 2997, 'job': 'Producer', 'name': 'Scott Rudin', 'profile_path': '/zR8sdlGblto6dneAr2mckTowwEl.jpg'}, {'credit_id': '52fe4259c3a36847f80172fb', 'department': 'Production', 'gender': 0, 'id': 8449, 'job': 'Producer', 'name': 'Ian MacNeil', 'profile_path': None}, {'credit_id': '52fe4259c3a36847f8017301', 'department': 'Production', 'gender': 2, 'id': 8401, 'job': 'Executive Producer', 'name': 'Mark Huffam', 'profile_path': None}, {'credit_id': '52fe4259c3a36847f8017307', 'department': 'Sound', 'gender': 2, 'id': 1551, 'job': 'Original Music Composer', 'name': 'Philip Glass', 'profile_path': '/5xhnji5hjwJHbWer6nwjFdM9GAB.jpg'}, {'credit_id': '52fe4259c3a36847f801730d', 'department': 'Camera', 'gender': 0, 'id': 3285, 'job': 'Director of Photography', 'name': 'Seamus McGarvey', 'profile_path': '/yXEsxEMHlMDemBy8JrHZFAmd3uD.jpg'}, {'credit_id': '52fe4259c3a36847f8017313', 'department': 'Editing', 'gender': 2, 'id': 8307, 'job': 'Editor', 'name': 'Peter Boyle', 'profile_path': None}, {'credit_id': '52fe4259c3a36847f8017319', 'department': 'Production', 'gender': 1, 'id': 2485, 'job': 'Casting', 'name': 'Patsy Pollock', 'profile_path': None}, {'credit_id': '52fe4259c3a36847f801731f', 'department': 'Production', 'gender': 0, 'id': 8450, 'job': 'Casting', 'name': 'Daniel Swee', 'profile_path': None}, {'credit_id': '52fe4259c3a36847f8017325', 'department': 'Art', 'gender': 1, 'id': 471, 'job': 'Production Design', 'name': 'Maria Djurkovic', 'profile_path': None}, {'credit_id': '52fe4259c3a36847f801732b', 'department': 'Art', 'gender': 2, 'id': 6998, 'job': 'Art Direction', 'name': 'Nick Palmer', 'profile_path': None}, {'credit_id': '52fe4259c3a36847f8017331', 'department': 'Art', 'gender': 0, 'id': 6999, 'job': 'Set Decoration', 'name': 'Philippa Hart', 'profile_path': None}, {'credit_id': '52fe4259c3a36847f8017337', 'department': 'Costume & Make-Up', 'gender': 1, 'id': 5493, 'job': 'Costume Design', 'name': 'Ann Roth', 'profile_path': None}, {'credit_id': '52fe4259c3a36847f801733d', 'department': 'Sound', 'gender': 0, 'id': 1116795, 'job': 'Music', 'name': 'Richard Strauss', 'profile_path': '/aj0UtCYClNx2hye8eVBu7LAMx3h.jpg'}, {'credit_id': '52fe4259c3a36847f8017343', 'department': 'Writing', 'gender': 2, 'id': 8402, 'job': 'Novel', 'name': 'Michael Cunningham', 'profile_path': '/20LFRf5uVEuvK8g1CUheqchMMUu.jpg'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# Name: crew, Length: 2984, dtype: int64
# "revenue"
# Nb of unique values: 2850
# 6000000       10
# 11000000      10
# 10000000       9
# 500000         8
# 12000000       6
# 5000000        6
# 13000000       5
# 1000000        5
# 14000000       5
# 4000000        5
# 20000000       5
# 1              4
# 1500000        4
# 25000000       4
# 2500000        4
# 17000000       4
# 102000000      4
# 25             3
# 1300000        3
# 18000000       3
# 2200000        3
# 4100000        3
# 7000000        3
# 7900000        3
# 8              3
# 8500000        3
# 7800000        3
# 3000000        3
# 10400000       3
# 3              3
#               ..
# 33000337       1
# 641            1
# 35456          1
# 2683519        1
# 254134910      1
# 6488144        1
# 3662459        1
# 108539911      1
# 1506249360     1
# 50000000       1
# 9448082        1
# 41480851       1
# 40590000       1
# 288752301      1
# 112462508      1
# 3665069        1
# 10609321       1
# 56359980       1
# 4635300        1
# 53898845       1
# 2042530        1
# 28900000       1
# 19776159       1
# 8303261        1
# 1548955        1
# 33697647       1
# 15000          1
# 54215416       1
# 5659286        1
# 448000000      1
# Name: revenue, Length: 2850, dtype: int64

# %% [markdown]
# #### Ideas of influence on the overall worldwide box office revenue:
# * belong to a famous collection (col: belongs_to_collection)
# * budget
# * genres (col: genres, which can be one-hot-encoding)
# * original_language
# * original_title
# * production_companies (col: production_companies, which can be one-hot-encoding)
# * production_countries (col: production_countries, which can be one-hot-encoding)
# * release_date --> to transform into dates, to get the year, the month and the week day of release
# * runtime
# * spoken_languages (col: spoken_languages, which can be one-hot-encoding)
# * status: Released/Rumored --> check that Rumored, there is 0 revenue.
# * keywords description (col: Keywords, which can be one-hot-encoding) --> but sometimes, can be too specific.
#
# #### Column not very useful / to investigate to understand ?
# * col: homepage --> what for old movies
# * col: imdb_id
# * col: overview --> need to analyse a whole summary --> sentiment analyis ? key_words ?
# * col: tagline --> need to analyse a whole sentence --> sentiment analyis ? key_words ?
# * col: popularity --> what scale ?
# * col: poster_path --> maybe if not poster_path, not a lot of advertisement
# * col: title --> it is useful or do we need to transform it --> need to analyse a whole sentence --> key_words ?
# * col: cast --> can be interpreted to detect a famous actor (therefore, compared with previous movies, so sort movies by date)
#
# #### Output col: revenue

# %% [markdown]
# #### Analysis of col 'status'

# %%
column = 'status'
print(train_df[column].value_counts())
train_df.loc[(train_df[column] == 'Rumored'), 'revenue']
# Out:
# Released    2996
# Rumored        4
# Name: status, dtype: int64
# 609       273644
# 1007          60
# 1216    13418091
# 1618      229000
# Name: revenue, dtype: int64

# %% [markdown]
# #### Analysis of one-hot-encoding columns

# %% [markdown]
# ##### belongs_to_collection col

# %%
column = 'belongs_to_collection'
translation_collections_dict = get_translation_dict(train_df, column, 'id')
print(len(translation_collections_dict)) #422 collections
# Out:
# 422

# %% [markdown]
# ##### genres

# %%
column = 'genres'
translation_genres_dict = get_translation_dict(train_df, column, 'id')
print(len(translation_genres_dict)) #20 genres
# Out:
# 20

# %% [markdown]
# ##### production_companies

# %%
column = 'production_companies'
translation_prod_companies_dict = get_translation_dict(train_df, column, 'id')
print(len(translation_prod_companies_dict)) #3712 production companies
# Out:
# 3712

# %% [markdown]
# ##### production_countries

# %%
column = 'production_countries'
translation_prod_countries_dict = get_translation_dict(train_df, column, 'iso_3166_1')
print(len(translation_prod_countries_dict)) #74 production countries
# Out:
# 74

# %% [markdown]
# ##### spoken_languages

# %%
column = 'spoken_languages'
translation_spoken_lang_dict = get_translation_dict(train_df, column, 'iso_639_1')
print(len(translation_spoken_lang_dict)) #79 spoken languages
# Out:
# 79

# %% [markdown]
# ##### keywords

# %%
column = 'Keywords'
translation_keywords_dict = get_translation_dict(train_df, column, 'id')
print(len(translation_keywords_dict)) #7400 keywords --> too many keywords for a first application
# Out:
# 7400

# %% [markdown]
# ##### original_language

# %%
column = 'original_language'
list_languages = list(train_df[column].value_counts().index)
len(list_languages) # 36 languages
# Out:
# 36

# %% [markdown]
# #### release_date col

# %%
# convert it to datetime
train_df['release_date'] = pd.to_datetime(train_df['release_date'])
# add columns year and month
train_df['year'] = train_df['release_date'].map(lambda date: date.year)
train_df['month'] = train_df['release_date'].map(lambda date: date.month)
train_df['dayofweek'] = train_df['release_date'].map(lambda date: date.dayofweek)

# %%
print(len(train_df.columns))
print(train_df.columns[0:10])
# Out:
# 26
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity'],
#       dtype='object')

# %%
columns = ['id', 'belongs_to_collection', 'budget', 'genres', 'original_language', 'popularity', 'production_companies', 
           'production_countries', 'release_date', 'runtime', 'spoken_languages', 
           'Keywords', 'revenue']

# %% [markdown]
# #### Production companies

# %%
set_unique_combination_values = train_df['production_companies'].value_counts()
print(f'For 3000rows, nb of production companies: {len(set_unique_combination_values)}')
# Out:
# For 3000rows, nb of production companies: 2383

# %%
dict_production_companies = get_translation_dict(train_df, 'production_companies', 'id')
# 3695 production_companies
# 2383 combinations of production_companies (for 3000 movies)

# %%
# test for Paramount Production company
test_paramount_appearance = {name for name in dict_production_companies.values() if 'Paramount' in name}
test_paramount_appearance
# Out:
# {'Paramount',
#  'Paramount Animation',
#  'Paramount Classics',
#  'Paramount Pictures',
#  'Paramount Vantage'}

# %%
# try to simplify complicated names
useless_info_inside_title = ['Picture', 'Image', 'Animation', 'Classic', 'Vantage', 'Film', 'Production', 'Entertainment', 
                             'Studio', 'Inc.', 'Inc', ', The', 'L.P.', 'Company']

def simplify_prod_companies_names(list_unique_prod_companies: [str], list_useless_info: [str]) -> dict:
    dict_simplified_name_prod_companies = dict()
    for complicated_name in list_unique_prod_companies:
        simplified_name = complicated_name
        for replacement in [(info + 's', '') for info in list_useless_info]:
            simplified_name = simplified_name.replace(*replacement)
        for replacement in [(info, '') for info in list_useless_info]:
            simplified_name = simplified_name.replace(*replacement)
        simplified_name = simplified_name.strip()
        dict_simplified_name_prod_companies[complicated_name] = simplified_name
    return dict_simplified_name_prod_companies

# %%
list_unique_prod_companies = list(dict_production_companies.values())
dict_simplified_name_prod_companies = simplify_prod_companies_names(list_unique_prod_companies, useless_info_inside_title)

# %%
# plot the frequency of appearances of production companies
# get simpified names and frequencies
simplified_production_name_freq = dict()
for collection, frequency in set_unique_combination_values.iteritems():
    for production in ast.literal_eval(collection):
        complicated_production_name = production['name']
        previous_frequency = simplified_production_name_freq.get(dict_simplified_name_prod_companies[complicated_production_name], 0)
        simplified_production_name_freq[dict_simplified_name_prod_companies[complicated_production_name]] = previous_frequency + frequency
        
iter_nb_companies = 0
for v in simplified_production_name_freq.values():
    if v > 15:
        iter_nb_companies += 1
print(f'For 3000rows, nb of production companies whose frequency is bigger than 15 times :{iter_nb_companies}')

famous_prod_companies =[name for name, frequency in simplified_production_name_freq.items() if frequency > 15]
print(famous_prod_companies)
# Out:
# For 3000rows, nb of production companies whose frequency is bigger than 15 times :47
# ['Paramount', 'Universal', 'Metro-Goldwyn-Mayer (MGM)', 'Warner Bros.', 'Twentieth Century Fox  Corporation', 'Columbia', 'New Line Cinema', 'Touchstone', 'TriStar', 'Orion', 'Walt Disney', 'United Artists', 'Columbia  Corporation', 'Miramax', 'Morgan Creek', 'Hollywood', 'Focus Features', 'Dimension', 'Amblin', 'Fox 2000', 'Imagine', 'Summit', 'Blumhouse', 'Working Title', 'DreamWorks SKG', 'Regency Enterprises', 'Epsilon Motion', 'New Regency', 'BBC', 'Castle Rock', 'Canal', 'Lionsgate', '4', 'Canal+', 'Fox Searchlight', 'Village Roadshow', 'Original', 'Dune', 'Millennium', 'TF1', 'Spyglass', 'TSG', 'Participant Media', 'Screen Gems', 'Legendary', 'Relativity Media', 'Babelsberg']

# %% [markdown]
# #### Keywords

# %%
set_unique_combination_values = train_df['Keywords'].value_counts()
print(f'For 3000rows, nb of production companies: {len(set_unique_combination_values)}')
# Out:
# For 3000rows, nb of production companies: 2648

# %%
dict_keywords = get_translation_dict(train_df, 'Keywords', 'id')
# 7400 keywords
# 2648 combination of keywords

# %%
# plot the frequency of appearances of production companies
keywords_frequency_dict = dict()
for collection, frequency in set_unique_combination_values.iteritems():
    for item in ast.literal_eval(collection):
        keyword = item['name']
        previous_frequency = keywords_frequency_dict.get(keyword, 0)
        keywords_frequency_dict[keyword] = previous_frequency + frequency
keywords_frequency_dict
# Out:
# {'independent film': 155,
#  'woman director': 175,
#  'duringcreditsstinger': 134,
#  'suspense': 67,
#  'biography': 77,
#  'sport': 82,
#  'dystopia': 73,
#  'american football': 9,
#  'musical': 49,
#  'romantic comedy': 25,
#  'bicycle': 4,
#  'cycling': 2,
#  'bicycle race': 2,
#  'skab under tv': 3,
#  '√òverste hylde': 3,
#  'foran': 2,
#  'stand-up comedy': 6,
#  'kung fu': 12,
#  'hitman': 26,
#  'found footage': 19,
#  'animation': 17,
#  'new york': 47,
#  'monster': 26,
#  'skyscraper': 2,
#  'mutant': 14,
#  'restaurant': 15,
#  'human animal relationship': 7,
#  'mutation': 6,
#  'tv station': 4,
#  'dying and death': 34,
#  'water': 5,
#  'research station': 2,
#  'fur': 3,
#  'bat': 3,
#  'current': 1,
#  'electric shock': 3,
#  'cleverness': 1,
#  'gremlin': 2,
#  'cowardliness': 5,
#  'freedom of speech': 2,
#  'social activism': 1,
#  'dissident': 1,
#  'chinese communists': 3,
#  'sichuan earthquake': 1,
#  'contemporary art': 1,
#  'twitter': 1,
#  'social media': 1,
#  'based on novel': 111,
#  'captain': 3,
#  'boat': 9,
#  'obsession': 17,
#  'shipwreck': 10,
#  'stroke of fate': 3,
#  'whale': 8,
#  'walrus': 1,
#  'revenge': 73,
#  'love triangle': 25,
#  'baby': 17,
#  'sequel': 66,
#  'pregnancy': 19,
#  'unknown father': 1,
#  'pregnant woman': 2,
#  'childbirth': 3,
#  'sitting on a toilet': 4,
#  'ultrasound': 1,
#  'human evolution': 1,
#  'parent child relationship': 16,
#  'squirrel': 1,
#  'ice': 5,
#  'loss of child': 7,
#  'mammoth': 4,
#  'sloth': 2,
#  'stone age': 3,
#  'prehistoric': 4,
#  'saber-toothed tiger': 3,
#  'cavemen': 2,
#  'prehistoric creature': 4,
#  'prehistoric adventure': 3,
#  'prehistoric times': 3,
#  'prehistoric man': 1,
#  'foreigner': 2,
#  'martial arts': 31,
#  'katana': 1,
#  'bravery': 3,
#  'rice': 1,
#  'market': 4,
#  'tragic hero': 5,
#  'racism': 12,
#  'sadist': 3,
#  'master': 1,
#  'wing chun': 1,
#  'bayonet': 2,
#  'paris': 37,
#  'bomb': 12,
#  'vororte': 3,
#  'parkour': 2,
#  'gang': 23,
#  'undercover cop': 6,
#  'miami': 5,
#  'corruption': 33,
#  'capitalism': 7,
#  'cuba': 5,
#  'prohibition': 5,
#  'brother sister relationship': 30,
#  'loss of sister': 1,
#  'cocaine': 6,
#  'cult film': 7,
#  'bitterness': 1,
#  'wish': 4,
#  'mask': 11,
#  'passion': 2,
#  'forbidden love': 11,
#  'love': 64,
#  'car journey': 6,
#  'transportation': 2,
#  'auto': 7,
#  'human trafficking': 2,
#  'female friendship': 8,
#  'road trip': 18,
#  'loneliness': 12,
#  'wedding': 40,
#  'unspoken love': 1,
#  'nudity': 57,
#  'funeral': 15,
#  'past': 7,
#  'spectacle': 3,
#  'ukraine': 3,
#  'russia': 12,
#  'fairy tale': 9,
#  'legend': 5,
#  'quiz': 1,
#  'sword fight': 8,
#  'gold coin': 2,
#  'speaking horse': 1,
#  'artificial intelligence': 14,
#  'simulation': 1,
#  'computer program': 3,
#  'virtual reality': 8,
#  'murder': 123,
#  'los angeles': 48,
#  'composer': 3,
#  'mentor': 5,
#  'deaf-mute': 1,
#  'apprentice': 3,
#  'private life': 1,
#  'music': 17,
#  'disabled': 7,
#  'brother brother relationship': 34,
#  'invasion': 5,
#  'remake': 31,
#  'guerrilla warfare': 1,
#  'north korean': 1,
#  'italy': 9,
#  'poker': 6,
#  'casino': 7,
#  'terrorist': 22,
#  'banker': 1,
#  'money': 25,
#  'free running': 1,
#  'torture': 18,
#  'british secret service': 10,
#  'montenegro': 1,
#  'journalist': 26,
#  'cook': 3,
#  'drug dealer': 19,
#  'mystery': 4,
#  'bollywood': 6,
#  'police corruption': 6,
#  'crime': 18,
#  'india': 13,
#  'missing husband': 1,
#  'nerve gas': 1,
#  'magic': 30,
#  'fantasy': 9,
#  'dragon': 5,
#  'cuentos': 1,
#  'terramar': 1,
#  'anime': 6,
#  'flying': 4,
#  'becoming an adult': 14,
#  'fairy': 3,
#  'child hero': 3,
#  'pirate gang': 2,
#  'mermaid': 6,
#  'pirate': 10,
#  'native peoples': 3,
#  'horse race': 5,
#  'auction': 1,
#  'clerk': 4,
#  'business': 8,
#  'new york city': 31,
#  'dark comedy': 20,
#  'lake': 9,
#  'honeymoon': 3,
#  'woods': 4,
#  'sleepwalking': 1,
#  'mumblegore': 8,
#  'talking animal': 11,
#  'ape': 4,
#  'japan': 16,
#  'prostitute': 34,
#  'hotel': 24,
#  'hallucination': 13,
#  'interview': 8,
#  'investigation': 41,
#  'junkyard': 1,
#  'interrogation': 5,
#  'stranger': 4,
#  'psychosis': 1,
#  'record player': 1,
#  'mental hospital': 1,
#  'neo-noir': 17,
#  'personality disorder': 2,
#  'serial kiler': 1,
#  'scam': 5,
#  'weight lifting': 1,
#  'weightlifting': 1,
#  'prison': 50,
#  'snake': 5,
#  'conciliation': 1,
#  'observer': 3,
#  'arrest': 6,
#  'triade': 1,
#  'counterfeit': 1,
#  'hong kong': 5,
#  'police officer': 16,
#  'beach': 12,
#  'bride': 7,
#  'chance': 4,
#  'risk': 1,
#  'relation': 3,
#  'long island': 3,
#  'comedy': 16,
#  'scuba diving': 6,
#  'unfaithfulness': 4,
#  'art gallery': 3,
#  'dance class': 1,
#  'opposites attract': 4,
#  'caribbean': 4,
#  'commitment': 1,
#  'dance club': 3,
#  'neurotic': 2,
#  'bagpipes': 1,
#  'chance encounter': 1,
#  'insurance risk manager': 1,
#  'alien': 34,
#  'escape': 34,
#  'alien invasion': 7,
#  'alien infection': 1,
#  'sleeping': 1,
#  'doppelganger': 3,
#  'news report': 2,
#  'text messaging': 1,
#  'siren': 2,
#  'contamination': 1,
#  'suicide': 33,
#  'male nudity': 27,
#  'female nudity': 53,
#  'shotgun': 7,
#  'motel': 13,
#  'highway': 8,
#  'police': 64,
#  'psychopath': 22,
#  'travel': 11,
#  'gore': 18,
#  'serial killer': 29,
#  'blood': 28,
#  'slasher': 19,
#  'crash': 2,
#  'extreme violence': 10,
#  'violence': 87,
#  'country': 1,
#  'trailer': 2,
#  'wrecking yard': 1,
#  'kiddnapping': 1,
#  'tracking device': 2,
#  'person in car trunk': 1,
#  'dialogue': 4,
#  'talking': 2,
#  'soulmates': 3,
#  'walking': 1,
#  'bookshop': 3,
#  "love of one's life": 23,
#  'author': 11,
#  'sex': 71,
#  'handcuffs': 7,
#  'waitress': 11,
#  'fight': 23,
#  'fireworks': 6,
#  'volcano': 5,
#  'navy': 6,
#  'convertible': 1,
#  'inmate': 1,
#  'escort': 3,
#  'military': 18,
#  'embezzlement': 1,
#  'nervous': 1,
#  'terror': 8,
#  'sadistic': 3,
#  'detective': 38,
#  'blackout': 5,
#  'capital punishment': 1,
#  'maniac': 6,
#  'rage': 4,
#  'killer': 14,
#  'electricity': 1,
#  'evil': 11,
#  'madman': 1,
#  'insane': 2,
#  'exotic island': 8,
#  'dna': 4,
#  'paleontology': 2,
#  'tyrannosaurus rex': 2,
#  'triceratops': 1,
#  'brontosaurus': 1,
#  'electric fence': 1,
#  'island': 17,
#  'dinosaur': 12,
#  'amusement park': 7,
#  'theme park': 2,
#  'jurassic park': 1,
#  'ku klux klan': 2,
#  'doomed man': 2,
#  'artist': 6,
#  'success': 9,
#  'relationship problems': 4,
#  'alcoholism': 8,
#  'falling in love': 9,
#  'vampire': 29,
#  'dracula': 10,
#  'bite': 7,
#  'battle': 14,
#  '15th century': 3,
#  'ottoman empire': 2,
#  'vlad': 2,
#  'fang vamp': 6,
#  'tepes': 1,
#  'texas': 18,
#  'sadism': 10,
#  'leatherface': 2,
#  'hitchhiker': 5,
#  'cross dressing': 2,
#  'chainsaw': 4,
#  'cannibal': 2,
#  'splatter': 2,
#  'skin': 1,
#  'psychos': 1,
#  'chinatown': 1,
#  'animal': 8,
#  'country music': 4,
#  'country singer': 1,
#  'baseball': 16,
#  'fanatic': 4,
#  'teacher': 22,
#  'red sox': 1,
#  'fenway park': 2,
#  'planned murder': 8,
#  'banquet': 1,
#  'victim of murder': 2,
#  'footlocker': 1,
#  'strangle': 1,
#  'rope': 2,
#  'based on play or musical': 19,
#  'long take': 3,
#  'berlin': 9,
#  'assassin': 24,
#  'amnesia': 17,
#  'sniper': 11,
#  'lie': 11,
#  'on the run': 13,
#  'shootout': 20,
#  'espionage': 3,
#  'foot chase': 6,
#  'car chase': 15,
#  'exploding house': 2,
#  'though guy': 2,
#  'one against many': 2,
#  'rail car': 1,
#  'dark past': 2,
#  'moscow': 6,
#  'hand to hand combat': 5,
#  'oregon': 3,
#  'olympic games': 8,
#  'runner': 2,
#  'mountain': 16,
#  'kidnapping': 41,
#  'wind': 1,
#  'wolf': 8,
#  'narration': 10,
#  'snow': 14,
#  'twins': 8,
#  'death': 32,
#  'missing son': 2,
#  'indigenous peoples': 1,
#  'godzilla': 3,
#  'giant monster': 4,
#  'destruction': 3,
#  'kaiju': 2,
#  'toyko': 1,
#  'homosexuality': 14,
#  'transgender': 3,
#  'family': 45,
#  'lgbt': 11,
#  'drag': 3,
#  'romantic drama': 3,
#  'social issues': 5,
#  'self-liberation': 1,
#  'fearless': 1,
#  'sex change operation': 1,
#  'chess': 3,
#  'london england': 38,
#  'father son relationship': 44,
#  'time travel': 25,
#  'technology': 7,
#  'internet': 7,
#  'hacking': 2,
#  'teenager': 61,
#  'game': 5,
#  'adaptation': 5,
#  'dare': 2,
#  'cellphone video': 1,
#  'based on young adult novel': 17,
#  'smartphone': 2,
#  'taking a risk': 1,
#  'china': 11,
#  'modern china': 1,
#  'return of son': 1,
#  'suicide jump': 1,
#  'fish': 3,
#  'rock star': 3,
#  'vacation': 11,
#  'rock concert': 1,
#  'date': 5,
#  'tattoo': 6,
#  'submarine': 9,
#  'flirt': 5,
#  'ship': 16,
#  'naval officer': 2,
#  'sinkendes schiff': 1,
#  'dictator': 3,
#  '1970s': 11,
#  'general': 5,
#  'naivety': 3,
#  'luxury': 1,
#  'oscar award': 8,
#  'charisma': 1,
#  'polygamy': 1,
#  'uganda': 1,
#  'dictatorship': 1,
#  'train station': 2,
#  'new jersey': 4,
#  'small person': 1,
#  'friendship': 72,
#  'newfoundland': 2,
#  'boston': 7,
#  'revolution': 7,
#  'spider': 5,
#  'leopard': 1,
#  'haiti': 2,
#  'amazon': 3,
#  'superstition': 1,
#  'buried alive': 5,
#  'jungle': 15,
#  'punched in the face': 3,
#  'tarantula': 2,
#  'cock fighting': 1,
#  'chained': 2,
#  'voice over': 3,
#  'anthropologist': 1,
#  'zombification': 2,
#  'rite': 1,
#  'grave robbing': 3,
#  'oil lamp': 1,
#  'death certificate': 1,
#  'airliner': 1,
#  'puffer fish': 1,
#  'reference to jean claude duvalier': 1,
#  'man on fire': 1,
#  'genital mutilation': 1,
#  'viper': 1,
#  'spy': 21,
#  'gun': 17,
#  'vulgar': 2,
#  'hooligan': 1,
#  'vulgarity': 2,
#  'soccer': 6,
#  'gay': 28,
#  'self-fulfilling prophecy': 2,
#  'journalism': 7,
#  'identity': 10,
#  'dream': 21,
#  'literature research': 1,
#  'literature': 4,
#  'metal detector': 1,
#  'film director': 5,
#  'ex-cop': 7,
#  'reporter': 17,
#  'scream': 3,
#  'series of murders': 4,
#  'duck': 2,
#  'physicist': 2,
#  'extraterrestrial': 3,
#  'anthropomorphism': 10,
#  'alternative reality': 2,
#  'alcohol': 21,
#  'secret': 24,
#  'birthday': 8,
#  'brother': 6,
#  'party': 28,
#  'friends': 28,
#  'prank': 5,
#  'bully': 6,
#  'drug': 52,
#  'gay man': 2,
#  'naked': 2,
#  'invite': 1,
#  'san francisco': 13,
#  'marriage proposal': 11,
#  'ruling class': 1,
#  'interracial relationship': 7,
#  'african american': 10,
#  'dinner': 3,
#  'doctor': 19,
#  'widower': 4,
#  'miscegenation': 2,
#  'publisher': 1,
#  'witch': 14,
#  'black magic': 6,
#  'steampunk': 4,
#  'good vs evil': 9,
#  'troll': 4,
#  'witchcraft': 1,
#  'witch hunt': 1,
#  'witch hunter': 3,
#  'evil witch': 2,
#  'hansel and gretel': 1,
#  'guns': 2,
#  '3d': 40,
#  'supernatural': 10,
#  'mirror': 5,
#  'skepticism': 2,
#  'ghost': 22,
#  'puberty': 5,
#  'first time': 7,
#  'heroism': 4,
#  'navy seal': 3,
#  'pistol': 8,
#  'secret plot': 2,
#  'military life': 1,
#  'valor': 1,
#  'terrorist plot': 2,
#  'navy life': 1,
#  'national security': 1,
#  'pregnant wife': 3,
#  'silver star': 1,
#  'counter plot': 1,
#  'parachute': 1,
#  'president': 4,
#  'air force one': 2,
#  'explosion': 27,
#  'finland': 1,
#  'suitcase': 2,
#  'omaha': 1,
#  'on the road': 2,
#  'downsizing': 1,
#  'cross country': 1,
#  'infidelity': 23,
#  'politician': 9,
#  'airplane crash': 3,
#  'death of husband': 3,
#  'police sergeant': 2,
#  'death of wife': 4,
#  'fire': 15,
#  'hero': 15,
#  'career woman': 3,
#  'photography': 7,
#  'u.s. air force': 2,
#  'grocery': 1,
#  'jamaican': 1,
#  'meteorologist': 1,
#  'rescue boat': 1,
#  'marina': 1,
#  'city hall': 1,
#  'the flemish cap': 1,
#  'male camaraderie': 2,
#  'storm at sea': 3,
#  'android': 12,
#  'killer robot': 7,
#  'robot': 16,
#  'scientist': 22,
#  'dual role': 2,
#  'robot human relationship': 2,
#  'humanoid robot': 1,
#  'robbery': 36,
#  'bar': 12,
#  'winter': 13,
#  'blackmail': 20,
#  'bartender': 4,
#  'crime boss': 4,
#  'organized crime': 12,
#  'mobster': 14,
#  'pitbull': 1,
#  'church': 10,
#  'catholic': 6,
#  'brooklyn new york city': 3,
#  'ex-con': 4,
#  'super bowl': 1,
#  'abandoned puppy': 1,
#  'indigenous': 5,
#  'lover (female)': 6,
#  'pyramid': 4,
#  'sapient': 1,
#  'mountain village': 2,
#  'fighter': 5,
#  'primitive time': 1,
#  'smoking': 8,
#  'coffee': 2,
#  'autograph': 4,
#  'cigarette': 4,
#  'smalltalk': 1,
#  'jukebox': 1,
#  'gathering': 2,
#  'conversation': 2,
#  'addicted': 2,
#  'cousin': 1,
#  'emergency doctor': 1,
#  'irish-american': 3,
#  'immigrant': 5,
#  'gang war': 5,
#  'pickpocket': 2,
#  'gang of thieves': 1,
#  'butcher': 3,
#  'pig': 5,
#  'army': 16,
#  'rescue': 25,
#  'mexico': 10,
#  'eroticism': 11,
#  'quickie': 1,
#  'suspicion of murder': 10,
#  'seduction': 12,
#  'final exam': 1,
#  'extramarital affair': 19,
#  'africa': 8,
#  'cat': 8,
#  'lion': 4,
#  'lion cub': 1,
#  'cheetah': 1,
#  'poison': 5,
#  'hermes': 1,
#  'poseidon': 1,
#  'demigod': 1,
#  'golden fleece': 1,
#  'olympus': 2,
#  'kronos': 1,
#  'overthrow olympus': 1,
#  'detroit': 6,
#  'blacksmith': 1,
#  'east india trading company': 2,
#  'gold': 10,
#  'mutiny': 7,
#  'jamaica': 2,
#  'skeleton': 6,
#  'daughter': 29,
#  'governor': 8,
#  'wooden eye': 1,
#  'alcoholic': 16,
#  'swashbuckler': 4,
#  'aftercreditsstinger': 75,
#  'pirate ship': 1,
#  'capuchin monkey': 1,
#  'tortuga': 1,
#  'mother': 9,
#  'radio': 6,
#  'firemen': 9,
#  'future': 29,
#  'time': 5,
#  'race against time': 4,
#  'father': 9,
#  'history': 8,
#  'paranormal': 5,
#  'family relationships': 14,
#  'flashback': 20,
#  'phenomenon': 1,
#  'amateur radio': 1,
#  'aurora borealis': 1,
#  'altering history': 1,
#  'historian': 2,
#  'gump': 1,
#  'dying wish': 1,
#  'danger': 3,
#  'car race': 11,
#  'car mechanic': 3,
#  'car garage': 3,
#  'auto-tuning': 3,
#  'drifting': 1,
#  'car': 8,
#  'automobile racing': 5,
#  'black people': 12,
#  'isolation': 10,
#  'arbitrary law': 6,
#  'socially deprived family': 2,
#  'tree house': 2,
#  'wrong accusal': 1,
#  'farm worker': 1,
#  'intolerance': 1,
#  'exclusion': 1,
#  'court case': 10,
#  'defence': 1,
#  'right and justice': 8,
#  'court': 7,
#  'child': 10,
#  'death of daughter': 3,
#  'homicide detective': 2,
#  'kingdom': 4,
#  'lightsaber': 1,
#  'cult favorite': 2,
#  'dead body': 5,
#  'magical object': 2,
#  'fortress': 1,
#  'cyclops': 2,
#  'changeling': 1,
#  'greed': 5,
#  'family dinner': 3,
#  'masked killer': 3,
#  'massacre': 6,
#  'home invasion': 3,
#  'crossbow': 1,
#  'disc jockey': 6,
#  'loss of family': 6,
#  'comeback': 5,
#  'recording studio': 2,
#  'british': 7,
#  'ibiza': 1,
#  'based on true story': 35,
#  'slapstick': 6,
#  'ensemble cast': 7,
#  'cross country race': 2,
#  'turn of the century': 2,
#  'autism': 2,
#  'france': 12,
#  'nun': 6,
#  'sculpture': 2,
#  'mental asylum': 1,
#  'persecution': 1,
#  'based on true events': 11,
#  'separation from family': 2,
#  'estranged brother': 1,
#  'religious institution': 1,
#  'estranged mother': 1,
#  'farewell': 2,
#  'homesickness': 2,
#  'nasa': 7,
#  'extraterrestrial technology': 6,
#  'flying saucer': 1,
#  'adventure': 6,
#  'kids and family': 4,
#  'dog': 26,
#  'transvestism': 7,
#  'taxi': 9,
#  'subway': 8,
#  'shower': 4,
#  'one-night stand': 8,
#  'manipulation': 8,
#  'nightmare': 10,
#  'assault': 3,
#  'alter ego': 2,
#  'stalking': 5,
#  'psychiatrist': 12,
#  'desire': 5,
#  'guilt': 8,
#  'hitchcockian': 3,
#  'straight razor': 1,
#  'exhibitionism': 2,
#  'elevator': 5,
#  'dark secrets': 2,
#  'white gloves': 1,
#  'bedroom': 4,
#  'purse': 1,
#  'trunk': 1,
#  'elmore leonard': 2,
#  'loss of parents': 5,
#  'karate': 3,
#  'hoodlum': 11,
#  'edward ii': 1,
#  'male female relationship': 16,
#  'co-worker': 4,
#  'relationship': 22,
#  'mumblecore': 6,
#  'two man army': 2,
#  'consul': 1,
#  'crime lord': 3,
#  'art treasures': 1,
#  'reference to chelsea clinton': 1,
#  'roses are red poem': 1,
#  'norway': 1,
#  'undead': 4,
#  'zombie': 22,
#  'wintry': 1,
#  'circus': 6,
#  'bank robber': 5,
#  'heist': 9,
#  'bank heist': 1,
#  'motorcycle chase': 1,
#  'doo wop': 1,
#  'showbiz': 1,
#  'crowd': 1,
#  'black singer': 1,
#  'addict': 2,
#  'legal battle': 1,
#  'sister sister relationship': 18,
#  'in vitro fertilisation': 2,
#  'medical examiner': 2,
#  'kidney transplant ': 1,
#  'telekinesis': 4,
#  'psychokinesis': 1,
#  'psychic': 4,
#  'demon': 14,
#  'mayan': 1,
#  'cheating': 9,
#  'adolf hitler': 4,
#  'blonde': 5,
#  'funny nazi': 2,
#  'producer': 1,
#  'broadway musical': 2,
#  'muslim': 6,
#  'resistance': 10,
#  'algerian': 2,
#  'independence': 5,
#  'insurrection': 2,
#  'government': 18,
#  'united nations': 4,
#  'casbah': 1,
#  'gang of smugglers': 2,
#  'custody battle': 3,
#  'lawyer': 26,
#  'wrestling': 6,
#  'autobiography': 2,
#  'adultery': 26,
#  'candy': 2,
#  'high school': 49,
#  'marijuana': 15,
#  'injury': 2,
#  'franchise': 1,
#  'accident': 5,
#  'beer bottle': 1,
#  'real time': 1,
#  'candelabra': 1,
#  'reference to facebook': 2,
#  'padlock': 1,
#  'washington d.c.': 14,
#  'shield': 2,
#  'marvel comic': 17,
#  'superhero': 32,
#  'based on comic': 37,
#  'captain america': 1,
#  'marvel cinematic universe': 4,
#  'political thriller': 2,
#  'high school sports': 6,
#  'book editor': 1,
#  'holiday': 17,
#  'christmas party': 4,
#  'santa claus': 7,
#  'toy': 5,
#  'puppet': 11,
#  'christmas': 16,
#  'turboman': 1,
#  'navidad': 1,
#  'chocolate': 4,
#  'factory worker': 3,
#  'tv addicted person': 1,
#  'overweight child': 3,
#  'grandfather grandson relationship': 3,
#  'factory': 6,
#  'single': 10,
#  'competition': 20,
#  'world war i': 14,
#  'great depression': 4,
#  'caddy': 1,
#  'savannah': 2,
#  'cow': 3,
#  'hicktown': 2,
#  'small town sheriff': 1,
#  'rome': 3,
#  'expatriate': 1,
#  'episodic': 1,
#  'pop': 3,
#  'jazz': 7,
#  'tzar': 2,
#  'mafia boss': 4,
#  'folk music': 1,
#  'music business': 2,
#  'songwriter': 3,
#  'stock footage': 1,
#  'adult animation': 5,
#  'music hall': 1,
#  'jazz band': 2,
#  'generational': 1,
#  'jewish mafia': 1,
#  'heroin addiction': 2,
#  'helicopter': 23,
#  'iraq': 8,
#  'soldier': 30,
#  'iraq war': 3,
#  'trapped': 3,
#  'desert': 19,
#  'menage a trois': 2,
#  'atlanta': 3,
#  'garage': 6,
#  'single father': 5,
#  'pilot': 13,
#  'airplane': 23,
#  'guardian angel': 1,
#  'double life': 7,
#  'dc comics': 13,
#  'dual identity': 7,
#  'crime fighter': 8,
#  'fictional place': 5,
#  'gotham city': 5,
#  'credit card': 2,
#  'super powers': 14,
#  'lunatic asylum': 2,
#  'river': 11,
#  'expedition': 4,
#  'tribe': 4,
#  'explorer': 2,
#  'journey': 6,
#  '1920s': 5,
#  'mysterious lands': 1,
#  'anti hero': 4,
#  'secret agent': 8,
#  'fistfight': 9,
#  'burn victim': 1,
#  'st. petersburg russia': 5,
#  'islam': 1,
#  'car bomb': 3,
#  'fbi agent': 18,
#  'jealousy': 31,
#  'professor': 7,
#  'lolita': 3,
#  'lust': 6,
#  'illness': 4,
#  'underage': 1,
#  'voyeurism': 6,
#  'flirtation': 2,
#  'virginity': 5,
#  'mafia': 12,
#  'defense': 2,
#  'gangster': 19,
#  'policeman': 6,
#  'anarchic comedy': 4,
#  'bank': 10,
#  'mobile phone': 1,
#  'telephone': 3,
#  'weapon': 13,
#  'new love': 19,
#  'affection': 4,
#  'usa': 10,
#  'car accident': 9,
#  'death of mother': 3,
#  'father son reunion': 1,
#  'existentialism': 6,
#  'california': 18,
#  'earthquake': 5,
#  'catastrophe': 5,
#  'disaster film': 6,
#  'san andreas': 1,
#  'san andreas california': 1,
#  'rescue operation': 3,
#  'kung fu master': 2,
#  'child soldier': 1,
#  'age difference': 11,
#  'appearance': 1,
#  'body exchange': 3,
#  'genetics': 4,
#  'saudi arabia': 3,
#  'growing up': 4,
#  'insomnia': 5,
#  'orphan': 13,
#  'florida': 11,
#  'secret identity': 15,
#  'liberation of prisoners': 3,
#  'drug traffic': 4,
#  'floatplane': 1,
#  'transport of prisoners': 4,
#  'tank car': 1,
#  'florida keys': 2,
#  'coast guard': 2,
#  'historical': 2,
#  'edo period': 1,
#  'sengoku period': 1,
#  'shouwa period': 1,
#  'meiji period': 2,
#  'pornography': 5,
#  'conspiracy': 18,
#  'private investigator': 3,
#  'father daughter relationship': 11,
#  'private eye': 2,
#  'philosophy': 5,
#  'painting': 11,
#  'teen movie': 9,
#  ...}

# %%
famous_keywords =[name for name, frequency in keywords_frequency_dict.items() if frequency > 30]
print(f'For 3000 rows, nb of keywords which appear more than 30 times: {len(famous_keywords)}')
# Out:
# For 3000 rows, nb of keywords which appear more than 30 times: 52

# %% [markdown]
# #### Crew

# %%
dict_jobs_set = dict()
for index, movie_crew in train_df['crew'].iteritems():
    try:
        list_characters = ast.literal_eval(movie_crew)
        for character in list_characters:
            if character['job'] == 'Director':
                previous_set = dict_jobs_set.get('Director', set())
                previous_set.add(character['id'])
                dict_jobs_set['Director'] = previous_set
            elif character['job'] == 'Producer':
                previous_set = dict_jobs_set.get('Producer', set())
                previous_set.add(character['id'])
                dict_jobs_set['Producer'] = previous_set
    except ValueError:
        pass
print(f"Nb of unique directors for 3000 rows:{len(dict_jobs_set['Director'])}")
print(f"Nb of unique producers for 3000 rows:{len(dict_jobs_set['Producer'])}")
# Out:
# Nb of unique directors for 3000 rows:2043
# Nb of unique producers for 3000 rows:3554
